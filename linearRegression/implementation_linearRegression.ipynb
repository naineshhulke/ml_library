# %%
import numpy as np
import linearRegression as lr
import pandas as pd

# %%
# Importing data

file_data = pd.read_csv('linearRegression.txt',header=None)
X_data = np.array(file_data.values)

# %%
# separating out features 

X = X_data[:,0:2]
y = X_data[:,2]

# %%
# diving data into 70% training set and 30% test set

[m,n] = np.shape(X)

X_train = X[0:int(0.7*m),:]
y_train = y[0:int(0.7*m)]
X_test = X[int(0.7*m):,:]
y_test = y[int(0.7*m):]

# %%
#using linearRegression

stat = lr.optimize(X_train,y_train)

# %%
# trying values of alpha by a method ( parameters (alpha,no of iterations))

stat.plotJvsno(0.01,100)

# %%
stat.plotJvsno(0.1,100)

# %%
# o.1 seems to be suitable here, for the optimum theta... parameters: (alpha,no of iterations,regularisation (default=0)))

theta = stat.gettheta(0.1,100)
